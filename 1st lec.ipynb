# %%
print("hello","world",sep="-",end="$$")
print(" thiis is python")
# Out:
# hello-world$$ thiis is python

# %%
print("""ram     
            shyam""")
print("sita")
# Out:
# ram
#             shyam
# sita

# %%
a="this is python"
print(a,type(a))
a=10
print(a)
print(a,type(a))
# Out:
# this is python <class 'str'>
# 10
# 10 <class 'int'>

# %%
a=10
b=10.0
c=20
print(a,id(a))
print(b,id(b))
print(c,id(c))
# Out:
# 10 140717578110360
# 10.0 2864576578800
# 20 140717578110680

# %%
a=10
b=int(10.0)
print(a,id(a))
print(b,id(b))
# Out:
# 10 140717578110360
# 10 140717578110360

# %%
n1=input("enter a number")
print(n1,type(n1)   )
