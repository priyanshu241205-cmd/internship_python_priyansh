# %% [markdown]
# Q1  Practice:
# 	Dictionary
# 	Tuple
# 	Set

# %%
dict = {"key": "value" , "key2": "value2"}
print(type(dict))
print(dict["key"])
print(dict.keys())
tuple = ("value1", "value2", "value3")
print(type(tuple))
set = {"value1", "value2", "value3"}
print(type(set))
# Out:
# <class 'dict'>
# value
# dict_keys(['key', 'key2'])
# <class 'tuple'>
# <class 'set'>

# %% [markdown]
# Q2 Write a function for basic math operations like add multiply substract divide and use this in your program, take 2 number input from user

# %%
a = input("enter first number:")
b = input("enter second number:")

while True:
    print("""
    1. Addition
    2. Subtraction
    3. Multiplication
    4. Division
    5. exit""")

    choice = input("enter the number of your choice")
    if choice == "1":
        print("the sum is", int(a) + int(b))
    elif choice == "2":
        print("the difference is", int(a) - int(b))
    elif choice == "3":
        print("the product is", int(a) * int(b))
    elif choice == "4":
        print("the quotient is", int(a) / int(b))
    elif choice == "5":
        break
    else:
        print("invalid input")
# Out:
#     1. Addition
#     2. Subtraction
#     3. Multiplication
#     4. Division
#     5. exit
# the sum is 68
#
#     1. Addition
#     2. Subtraction
#     3. Multiplication
#     4. Division
#     5. exit

# %% [markdown]
# Q3 Write a program to check Palindrome Number
#
#  For example Number 12321 is a Palindrome Number, because 12321 is equal to its reverse Number 12321.
#
# Steps for checking Palindrome number :
#
#
# 1. Find reverse of the given number.
# 2. Compare that number with the reverse number.
# 3. If number and its reverse is equal then it is a Palindrome Number otherwise not.

# %%
a = input("enter a number:")
print(a)
if a == a[-1::-1]:
    print("the number is a palindrome")
else:
    print("the number is not a palindrome")
# Out:
# 34343
# the number is a palindrome
